# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Dataset 1: Crimes

# %% [markdown]
# The United States crimes dataset from kaggle contained 4 csv files, each containing information about crimes for cities. They csv files are separated by population ranges.
#
# * 'crime_40 _60.csv': dataset for population ranging from 40,000 to 60,000.
#
# * 'crime_60 _100.csv': dataset for population ranging from 60,000 to 100,000.
#
# * 'crime_100 _250.csv': dataset for population ranging from 100,000 to 250,000.
#
# * 'crime_250 _plus.csv': dataset for population greater than 250,000.
#
# We're interested in all the cities available in the dataset so we will combine the csvs into one dataframe.

# %% [markdown]
# First, inspecting each csv as a dataframe separately, checking columns and values.

# %%
import pandas as pd

# %%
pd.read_csv('crime/crime_250_plus.csv').head()
# Out:
#      states     cities population  total_crime  murder    rape  robbery  \
# 0   Alabama    Mobile3    248,431      6217.02   20.13   58.16   177.11
# 1    Alaska  Anchorage    296,188      6640.04    9.12  132.01   262.67
# 2   Arizona   Chandler    249,355      2589.08    2.01   52.13    56.95
# 3   Arizona    Gilbert    242,090      1483.75    2.07   16.11    21.07
# 4   Arizona   Glendale    249,273      5037.85    4.81   38.91   192.96
#
#   agrv_assault tot_violent_crime  burglary   larceny vehicle_theft  \
# 0       485.85            740.25  1,216.84  3,730.21        506.78
# 1       799.49          1,203.29    748.17  3,619.66      1,047.98
# 2       148.38            259.47    314.41  1,866.01        149.18
# 3        46.26             85.51    192.49  1,137.59         55.76
# 4       251.53            488.22    637.45  3,426.36        466.56
#
#   tot_prop_crim  arson
# 0      5,453.83  22.94
# 1      5,415.82  20.93
# 2      2,329.61    NaN
# 3      1,385.85  12.39
# 4      4,530.37  19.26

# %%
pd.read_csv('crime/crime_100_250.csv').head()
# Out:
#          states      cities population violent_crime murder  rape  robbery  \
# 0         Texas     Abilene    119,886         393.7    2.5  31.7    105.9
# 1          Ohio       Akron    198,390         886.6   12.1  84.2    290.8
# 2      Virginia  Alexandria    145,892         166.6      -   6.2     94.6
# 3  Pennsylvania   Allentown    119,334         547.2   12.6  45.3    313.4
# 4         Texas    Amarillo    196,576         650.1    5.1  56.0    141.4
#
#   agrv_assault prop_crime burglary  larceny vehicle_theft
# 0        253.6    3,664.3      865  2,656.7         142.6
# 1        499.5    5,057.7  1,728.4  2,965.9         363.4
# 2         65.8    2,049.5    192.6  1,633.4         223.5
# 3          176    3,857.2  1,045.8  2,503.1         308.4
# 4        447.7    4,527.5  1,061.7  3,145.9           320

# %%
pd.read_csv('crime/crime_40_60.csv').head()
# Out:
#          states                                cities population  \
# 0  Pennsylvania  Abington Township, Montgomery County     55,731
# 1        Oregon                                Albany     51,084
# 2     Louisiana                            Alexandria     48,449
# 3    California                           Aliso Viejo     48,999
# 4       Florida                     Altamonte Springs     42,296
#
#    violent_crime  murder  rape  robbery  agrv_assault  prop_crime  burglary  \
# 0          197.4     1.8  14.4     70.0         111.2      1979.1     296.1
# 1           86.1     0.0  19.6     45.0          21.5      3092.9     438.5
# 2         1682.2    18.6  28.9    293.1        1341.6      7492.4    2010.4
# 3           87.8     0.0   0.0     12.2          75.5       847.0     208.2
# 4          335.7     2.4  21.3     82.8         229.3      3057.0     427.9
#
#    larceny  vehicle_theft
# 0   1650.8           32.3
# 1   2470.4          184.0
# 2   5102.3          379.8
# 3    612.3           26.5
# 4   2463.6          165.5

# %%
pd.read_csv('crime/crime_60_100.csv').head()
# Out:
#        states    cities population violent_crime murder   rape  robbery  \
# 0  California   Alameda     75,467         212.0    1.3  11.91    106.0
# 1     Georgia    Albany     78,512       1,035.5    5.1   34.4    285.3
# 2    New York    Albany     98,187         816.8    4.1   43.8    253.6
# 3  California  Alhambra     84,469         176.4      -    2.4     78.1
# 4       Texas     Allen     88,783          61.9      -   12.4     14.6
#
#   agrv_assault prop_crime burglary  larceny vehicle_theft
# 0         92.8    2,507.1    392.2  1,723.9         390.9
# 1        710.7    6,369.7  1,793.4  4,291.1         285.3
# 2        515.3    4,420.1    903.4  3,359.9         156.8
# 3         95.9    2,271.8    384.8  1,585.2         301.9
# 4         34.9    1,612.9    242.2  1,321.2          49.6

# %% [markdown]
# After inspecting the csvs, combine all of them into a dataframe called crime.

# %%
import pandas as pd
import os

directories = ['crime', 'income']

dfs = []
filenames = os.listdir('crime')
filenames = [f for f in filenames if os.path.isfile(os.path.join('crime', f))]

for filename in filenames:
    df = pd.read_csv(f'crime/{filename}')
    dfs.append(df)
    
crime = pd.concat(dfs, ignore_index=True)

# %%
# checking the number of rows and columns
crime.shape
# Out:
# (975, 16)

# %% [markdown]
# Other EDA tasks such as inspecting individual columns and why there are duplicate values. There are multiple cities with the same name but from different states which is why there's duplicates in cities.

# %%
crime['cities'].nunique()
# Out:
# 889

# %%
crime['cities'].value_counts()
# Out:
# cities
# Springfield        5
# Lakewood           4
# Albany             3
# Columbus           3
# Newark             3
#                   ..
# Davis              1
# Daytona Beach      1
# Dearborn           1
# Deerfield Beach    1
# Yucaipa            1
# Name: count, Length: 889, dtype: int64

# %% [markdown]
# clean up cities column by remvoving uneccesary characters and values from the city name

# %%
crime['cities'] = crime['cities'].str.replace(r'\d+', '', regex=True)

# %%
crime['violent_crime'] = crime['violent_crime'].fillna(crime['tot_violent_crime'])
crime['prop_crime'] = crime['prop_crime'].fillna(crime['tot_prop_crim'])

# %% [markdown]
# Dropping columns because they're not present across all datasets. The crimes csv file for cities with population of 250,000+ contained 4 extra columns that are not in the other 3 datasets so there's no information on these columns for cities under 250,000 population and they appear as null values in the dataframe, so we can drop those columns.

# %%
crime.drop(columns = ['total_crime','arson', 'tot_prop_crim', 'tot_violent_crime'], inplace = True)

# %%
crime.dtypes
# Out:
# states            object
# cities            object
# population        object
# murder            object
# rape              object
# robbery          float64
# agrv_assault      object
# burglary          object
# larceny           object
# vehicle_theft     object
# violent_crime     object
# prop_crime        object
# dtype: object

# %%
crime.replace('-', '0', inplace=True)

# %%
    
crime['population'] = crime['population'].str.replace(',', '').astype(int)
crime['murder'] = crime['murder'].astype(float)
crime['rape'] = crime['rape'].astype(float)
#crime['agrv_assault'] = crime['agrv_assault'].astype(float)
#crime['burglary'] = crime['burglary'].astype(float)
#crime['larceny'] = crime['larceny'].str.replace(',', '').astype(float)
#crime['vehicle_theft'] = crime['vehicle_theft'].str.replace(',', '').astype(float)
#crime['violent_crime'] = crime['violent_crime'].str.replace(',', '').astype(float)
#crime['prop_crime'] = crime['prop_crime'].str.replace(',', '').astype(float)

# %%
crime.head()
# Out:
#      states     cities  population  murder    rape  robbery agrv_assault  \
# 0   Alabama     Mobile      248431   20.13   58.16   177.11       485.85
# 1    Alaska  Anchorage      296188    9.12  132.01   262.67       799.49
# 2   Arizona   Chandler      249355    2.01   52.13    56.95       148.38
# 3   Arizona    Gilbert      242090    2.07   16.11    21.07        46.26
# 4   Arizona   Glendale      249273    4.81   38.91   192.96       251.53
#
#    burglary   larceny vehicle_theft violent_crime prop_crime
# 0  1,216.84  3,730.21        506.78        740.25   5,453.83
# 1    748.17  3,619.66      1,047.98      1,203.29   5,415.82
# 2    314.41  1,866.01        149.18        259.47   2,329.61
# 3    192.49  1,137.59         55.76         85.51   1,385.85
# 4    637.45  3,426.36        466.56        488.22   4,530.37

# %%
crime.to_csv('cleaned_crime.csv', index=False)

# %% [markdown]
# #### Dataset 2: Median Income

# %%
median_income = pd.read_csv('med_income_23/ACSST1Y2023.S1902-Data.csv')

# %%
median_income = median_income[['NAME','S1902_C01_001E']]
median_income.drop(index=0, inplace = True)
median_income.rename(columns={'NAME': 'City', 'S1902_C01_001E': 'Median Income'}, inplace=True)

# %%
# Keeping data only for cities in the United States
us_states = [
    'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 
    'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
    'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 
    'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
    'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 
    'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 
    'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 
    'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 
    'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 
    'West Virginia', 'Wisconsin', 'Wyoming'
]

# Filter the DataFrame to keep only U.S. cities

median_income['City'] = median_income['City'].str.replace(r'\s*(city|town|CDP|municipality)\s*', '', regex=True).str.strip()


#df.drop(columns=['Location'], inplace=True)

median_income['State'] = median_income['City'].str.split(', ').str[1]  # Extract the state
median_income['City'] = median_income['City'].apply(lambda x: x.split(',')[0].strip())
df_us = median_income[median_income['State'].isin(us_states)]  # Keep only rows where the state is in the list

#df_us.drop(columns=['State'], inplace=True)

df_us
# Out:
#            City Median Income      State
# 1        Auburn         32859    Alabama
# 2    Birmingham         91740    Alabama
# 3        Dothan         30920    Alabama
# 4        Hoover         38178    Alabama
# 5    Huntsville         99557    Alabama
# ..          ...           ...        ...
# 639   Milwaukee        227173  Wisconsin
# 640     Oshkosh         28147  Wisconsin
# 641      Racine         31700  Wisconsin
# 642    Waukesha         30668  Wisconsin
# 643    Cheyenne         30643    Wyoming
#
# [642 rows x 3 columns]

# %%
df_us.to_csv('cleaned_income.csv', index=False)

# %% [markdown]
# #### Merging the Two Datasets

# %% [markdown]
# Now that the data is cleaned, we can merge it together so it can be more convenient for statistical analysis.

# %%
merged_data = pd.merge(df_us, crime, left_on=['City', 'State'], right_on=['cities','states'], how='inner')

# %%
merged_data.head()
# Out:
#          City Median Income    State   states      cities  population  murder  \
# 0      Auburn         32859  Alabama  Alabama      Auburn       54785     5.5
# 1  Birmingham         91740  Alabama  Alabama  Birmingham      213266    31.4
# 2      Dothan         30920  Alabama  Alabama      Dothan       66275     7.5
# 3      Hoover         38178  Alabama  Alabama      Hoover       82332     2.4
# 4  Huntsville         99557  Alabama  Alabama  Huntsville      183691     7.6
#
#    rape  robbery agrv_assault burglary  larceny vehicle_theft violent_crime  \
# 0  23.7     45.6        166.1    763.0   2646.7          93.1         240.9
# 1  71.3    460.9        954.2  2,205.7  4,239.8         488.6       1,517.8
# 2  45.3    150.9        277.6  1,336.9  2,894.0         196.2         481.3
# 3  15.8     55.9         30.4    477.3  2,067.2         103.2         104.5
# 4  39.2    248.2        628.2  1,178.6  3,476.5         386.5         923.3
#
#   prop_crime
# 0     3502.8
# 1    6,934.1
# 2    4,427.0
# 3    2,647.8
# 4    5,041.6

# %%
# Drop redundant columns
merged_data = merged_data.drop(['states', 'cities'], axis = 1)

# %%
merged_data.isnull().sum()
# Out:
# City              0
# Median Income     0
# State             0
# population        0
# murder            0
# rape             10
# robbery           0
# agrv_assault      0
# burglary          1
# larceny           0
# vehicle_theft     0
# violent_crime    10
# prop_crime        1
# dtype: int64

# %%
merged_data.fillna(0, inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# City             0
# Median Income    0
# State            0
# population       0
# murder           0
# rape             0
# robbery          0
# agrv_assault     0
# burglary         0
# larceny          0
# vehicle_theft    0
# violent_crime    0
# prop_crime       0
# dtype: int64

# %%
merged_data.head()
# Out:
#          City Median Income    State  population  murder  rape  robbery  \
# 0      Auburn         32859  Alabama       54785     5.5  23.7     45.6
# 1  Birmingham         91740  Alabama      213266    31.4  71.3    460.9
# 2      Dothan         30920  Alabama       66275     7.5  45.3    150.9
# 3      Hoover         38178  Alabama       82332     2.4  15.8     55.9
# 4  Huntsville         99557  Alabama      183691     7.6  39.2    248.2
#
#   agrv_assault burglary  larceny vehicle_theft violent_crime prop_crime
# 0        166.1    763.0   2646.7          93.1         240.9     3502.8
# 1        954.2  2,205.7  4,239.8         488.6       1,517.8    6,934.1
# 2        277.6  1,336.9  2,894.0         196.2         481.3    4,427.0
# 3         30.4    477.3  2,067.2         103.2         104.5    2,647.8
# 4        628.2  1,178.6  3,476.5         386.5         923.3    5,041.6

# %%
merged_data.to_csv('income_and_crimes.csv', index=False)

# %% [markdown]
# ## Further Analysis- Mulitple Linear Regression, Logistic Regression, K-Means

# %%
def check_non_numeric(df, columns):
    for col in columns:
        non_numeric_values = df[col].apply(lambda x: not isinstance(x, (int, float)))
        if non_numeric_values.sum() > 0:
            print(f"Column '{col}' has {non_numeric_values.sum()} non-numeric values.")

numeric_cols = ["Median Income", "population", "murder", "rape", "robbery", "agrv_assault",
                "burglary", "larceny", "vehicle_theft", "violent_crime", "prop_crime"]

check_non_numeric(merged_data, numeric_cols)
# Out:
# Column 'Median Income' has 483 non-numeric values.
# Column 'agrv_assault' has 445 non-numeric values.
# Column 'burglary' has 444 non-numeric values.
# Column 'larceny' has 445 non-numeric values.
# Column 'vehicle_theft' has 445 non-numeric values.
# Column 'violent_crime' has 437 non-numeric values.
# Column 'prop_crime' has 444 non-numeric values.

# %%
# Select only numeric columns before applying median
numeric_cols = ["Median Income", "agrv_assault", "burglary", "larceny",
                "vehicle_theft", "violent_crime", "prop_crime"]

# Remove commas and convert columns to numeric
for col in numeric_cols:
    merged_data[col] = merged_data[col].replace({",": ""}, regex=True)  # Remove commas
    merged_data[col] = pd.to_numeric(merged_data[col], errors="coerce")  # Convert to numeric

# Handle missing values only for numeric columns
merged_data[numeric_cols] = merged_data[numeric_cols].fillna(merged_data[numeric_cols].median())

# Verify if all columns are now numeric
# print(merged_data.dtypes)
merged_data
# Out:
#            City  Median Income      State  population  murder  rape  robbery  \
# 0        Auburn        32859.0    Alabama       54785     5.5  23.7     45.6
# 1    Birmingham        91740.0    Alabama      213266    31.4  71.3    460.9
# 2        Dothan        30920.0    Alabama       66275     7.5  45.3    150.9
# 3        Hoover        38178.0    Alabama       82332     2.4  15.8     55.9
# 4    Huntsville        99557.0    Alabama      183691     7.6  39.2    248.2
# ..          ...            ...        ...         ...     ...   ...      ...
# 478     Madison       134512.0  Wisconsin      237508     1.3  48.0    101.5
# 479     Oshkosh        28147.0  Wisconsin       66514     0.0  19.5     27.1
# 480      Racine        31700.0  Wisconsin       79055     5.1  39.2    266.9
# 481    Waukesha        30668.0  Wisconsin       71049     1.4  36.6     33.8
# 482    Cheyenne        30643.0    Wyoming       60969     0.0  34.4     34.4
#
#      agrv_assault  burglary  larceny  vehicle_theft  violent_crime  prop_crime
# 0           166.1     763.0   2646.7           93.1          240.9      3502.8
# 1           954.2    2205.7   4239.8          488.6         1517.8      6934.1
# 2           277.6    1336.9   2894.0          196.2          481.3      4427.0
# 3            30.4     477.3   2067.2          103.2          104.5      2647.8
# 4           628.2    1178.6   3476.5          386.5          923.3      5041.6
# ..            ...       ...      ...            ...            ...         ...
# 478         226.9     674.1   2483.3          106.9          377.7      3264.3
# 479         240.6     511.2   2022.1           55.6          287.2      2588.9
# 480         161.9    1392.7   2466.6          164.4          473.1      4023.8
# 481          78.8     327.9   1462.4           45.0          150.6      1835.4
# 482         160.7     418.2   2837.5          157.5          229.6      3413.2
#
# [483 rows x 13 columns]

# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# #### VIF for assumptions

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Select relevant numerical columns for VIF analysis
features = ["Median Income", "population", "murder", "rape", "robbery", 
            "agrv_assault", "burglary", "larceny", "vehicle_theft"]

X = merged_data[features]

# Add constant for intercept
X = sm.add_constant(X)

# Compute VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Display VIF results
print(vif_data)
# Out:
#          Feature        VIF
# 0          const  10.038037
# 1  Median Income   7.485113
# 2     population   7.436834
# 3         murder   2.588524
# 4           rape   1.495161
# 5        robbery   4.224075
# 6   agrv_assault   2.851675
# 7       burglary   2.921243
# 8        larceny   1.784274
# 9  vehicle_theft   1.672404

# %%
import statsmodels.api as sm

# Define dependent and independent variables
y = merged_data["violent_crime"]

# Selecting independent variables (excluding features with high VIF if necessary)
selected_features = ["murder", "rape", "robbery", 
                     "agrv_assault", "burglary", "larceny", "vehicle_theft"]

X = merged_data[selected_features]

# Add constant term for intercept
X = sm.add_constant(X)

# Fit the multiple linear regression model
model = sm.OLS(y, X).fit()

# Display regression results
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          violent_crime   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.564e+04
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):               0.00
# Time:                        13:11:55   Log-Likelihood:                -2188.3
# No. Observations:                 483   AIC:                             4393.
# Df Residuals:                     475   BIC:                             4426.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -2.6874      2.666     -1.008      0.314      -7.925       2.551
# murder            0.8624      0.226      3.818      0.000       0.419       1.306
# rape              1.1719      0.053     22.001      0.000       1.067       1.277
# robbery           0.9937      0.017     58.086      0.000       0.960       1.027
# agrv_assault      1.0020      0.008    126.413      0.000       0.986       1.018
# burglary          0.0037      0.004      0.954      0.340      -0.004       0.011
# larceny          -0.0037      0.001     -2.855      0.004      -0.006      -0.001
# vehicle_theft     0.0065      0.005      1.184      0.237      -0.004       0.017
# ==============================================================================
# Omnibus:                      880.651   Durbin-Watson:                   0.686
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           488318.533
# Skew:                         -11.724   Prob(JB):                         0.00
# Kurtosis:                     156.995   Cond. No.                     6.94e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.94e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.api as sm

# Get predicted values from the regression model
predicted_values = model.fittedvalues
residuals = model.resid

# Residual plot
plt.figure(figsize=(8,6))
sns.scatterplot(x=predicted_values, y=residuals)
plt.axhline(0, color='red', linestyle='--')
plt.title("Residual Plot")
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.show()

# %%
# Create scatter plots for each independent variable against violent crime

# List of selected features
selected_features = [ "murder", "rape", "robbery", 
                     "agrv_assault", "burglary", "larceny", "vehicle_theft"]

# Set figure size
plt.figure(figsize=(15, 12))

# Create subplots for each feature
for i, feature in enumerate(selected_features, 1):
    plt.subplot(3, 3, i)
    sns.scatterplot(x=merged_data[feature], y=merged_data["violent_crime"], alpha=0.5)
    plt.xlabel(feature)
    plt.ylabel("Violent Crime")
    plt.title(f"Violent Crime vs {feature}")

plt.tight_layout()
plt.show()

# Generate a correlation heatmap for selected features + violent crime
plt.figure(figsize=(10, 8))
sns.heatmap(merged_data[selected_features + ["violent_crime"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Selected Features with Violent Crime")
plt.show()

# %% [markdown]
# ### K-Means

# %% [markdown]
# #### Check for assumptions

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

# Select relevant features for clustering
cluster_features = ["Median Income", "violent_crime"]

# Standardize the features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_data[cluster_features])

# Determine the optimal number of clusters using the Elbow Method
wcss = []  # Within-cluster sum of squares
K_range = range(1, 10)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

# Fit K-Means clustering with the optimal number of clusters (determined visually from the Elbow Method)
optimal_k = 3  # Assuming elbow method suggests 3 clusters
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
merged_data["Cluster"] = kmeans.fit_predict(scaled_data)

# Define meaningful cluster labels
cluster_labels = {
    0: "Low Crime & High Income",
    1: "Moderate Crime & Moderate Income",
    2: "High Crime & Low Income"
}
merged_data["Cluster Label"] = merged_data["Cluster"].map(cluster_labels)

# Train a KNN classifier to predict clusters
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(scaled_data, merged_data["Cluster"])

# Prepare OLS regression model
X = sm.add_constant(merged_data[["Median Income", "population", "murder", "rape", "robbery", 
                                 "agrv_assault", "burglary", "larceny", "vehicle_theft"]])
y = merged_data["violent_crime"]
ols_model = sm.OLS(y, X).fit()

# Generate scatter plot to visualize clusters
plt.figure(figsize=(8,6))
sns.scatterplot(x=merged_data["Median Income"], y=merged_data["violent_crime"], hue=merged_data["Cluster"], 
                palette="viridis", s=100)
plt.title("K-Means Clustering of Cities Based on Income and Crime")
plt.xlabel("Median Income")
plt.ylabel("Violent Crime")
plt.legend(title="Cluster", labels=[cluster_labels[i] for i in range(optimal_k)])
plt.show()

# Display OLS results
ols_results = ols_model.summary()
ols_results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          violent_crime   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.215e+04
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):               0.00
# Time:                        14:26:53   Log-Likelihood:                -2187.6
# No. Observations:                 483   AIC:                             4395.
# Df Residuals:                     473   BIC:                             4437.
# Df Model:                           9
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -4.9137      3.267     -1.504      0.133     -11.333       1.505
# Median Income  3.249e-05      0.000      0.243      0.808      -0.000       0.000
# population     1.419e-05   5.92e-05      0.240      0.811      -0.000       0.000
# murder            0.8681      0.226      3.840      0.000       0.424       1.312
# rape              1.1740      0.054     21.902      0.000       1.069       1.279
# robbery           0.9929      0.017     57.669      0.000       0.959       1.027
# agrv_assault      1.0020      0.008    126.148      0.000       0.986       1.018
# burglary          0.0034      0.004      0.878      0.380      -0.004       0.011
# larceny          -0.0039      0.001     -2.917      0.004      -0.007      -0.001
# vehicle_theft     0.0063      0.006      1.110      0.267      -0.005       0.018
# ==============================================================================
# Omnibus:                      879.304   Durbin-Watson:                   0.697
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           484571.209
# Skew:                         -11.688   Prob(JB):                         0.00
# Kurtosis:                     156.400   Cond. No.                     4.01e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.01e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
